# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from scipy.stats import zscore

# %% [markdown]
# ### 1. Loading Data

# %%
train = pd.read_csv(r"C:\Users\YILMAZ\Desktop\appartments_train.csv")
test = pd.read_csv(r"C:\Users\YILMAZ\Desktop\appartments_test.csv")

# %% [markdown]
# ### 2. Dataset Overview

# %%
print(train.shape)
# Out:
# (156454, 34)

# %%
print(train.dtypes)
# Out:
# unit_id                        object
# obj_type                       object
# dim_m2                        float64
# n_rooms                       float64
# floor_no                      float64
# floor_max                     float64
# year_built                    float64
# dist_centre                   float64
# n_poi                         float64
# dist_sch                      float64
# dist_clinic                   float64
# dist_post                     float64
# dist_kind                     float64
# dist_rest                     float64
# dist_uni                      float64
# dist_pharma                   float64
# own_type                       object
# build_mat                      object
# cond_class                     object
# has_park                       object
# has_balcony                    object
# has_lift                       object
# has_sec                        object
# has_store                      object
# price_z                       float64
# src_month                      object
# loc_code                       object
# market_volatility             float64
# infrastructure_quality        float64
# neighborhood_crime_rate       float64
# popularity_index              float64
# green_space_ratio             float64
# estimated_maintenance_cost    float64
# global_economic_index         float64
# dtype: object

# %%
print(train.describe(include='all').T)
# Out:
#                                count unique               top    freq  \
# unit_id                       156454  82491  ff92f050e0b9869f      11
# obj_type                      122634      3          0d6c4dfc   73136
# dim_m2                      156454.0    NaN               NaN     NaN
# n_rooms                     156454.0    NaN               NaN     NaN
# floor_no                    128756.0    NaN               NaN     NaN
# floor_max                   154533.0    NaN               NaN     NaN
# year_built                  130741.0    NaN               NaN     NaN
# dist_centre                 156454.0    NaN               NaN     NaN
# n_poi                       156454.0    NaN               NaN     NaN
# dist_sch                    156324.0    NaN               NaN     NaN
# dist_clinic                 155883.0    NaN               NaN     NaN
# dist_post                   156266.0    NaN               NaN     NaN
# dist_kind                   156291.0    NaN               NaN     NaN
# dist_rest                   156063.0    NaN               NaN     NaN
# dist_uni                    152137.0    NaN               NaN     NaN
# dist_pharma                 156235.0    NaN               NaN     NaN
# own_type                      156454      3          12631efb  140897
# build_mat                      94455      2          7ceffe3b   73414
# cond_class                     39396      2          a2881958   22298
# has_park                      156454      2                no  113938
# has_balcony                   156454      2               yes   89655
# has_lift                      148727      2                no   74680
# has_sec                       156454      2                no  138878
# has_store                     156454      2                no   88578
# price_z                     156454.0    NaN               NaN     NaN
# src_month                     156454     11           2024-06   17213
# loc_code                      156454     15          693f303c   47502
# market_volatility           156454.0    NaN               NaN     NaN
# infrastructure_quality      130741.0    NaN               NaN     NaN
# neighborhood_crime_rate     156454.0    NaN               NaN     NaN
# popularity_index            156454.0    NaN               NaN     NaN
# green_space_ratio           156454.0    NaN               NaN     NaN
# estimated_maintenance_cost  156454.0    NaN               NaN     NaN
# global_economic_index       156454.0    NaN               NaN     NaN
#
#                                      mean            std        min  \
# unit_id                               NaN            NaN        NaN
# obj_type                              NaN            NaN        NaN
# dim_m2                          58.702447      23.278725      18.78
# n_rooms                          2.678634       0.916015        1.0
# floor_no                         3.334749       2.535675        1.0
# floor_max                        5.312859       3.311659        1.0
# year_built                    1986.010532      33.792722     1850.0
# dist_centre                      4.357027        2.90058      0.008
# n_poi                           20.611509      24.212745        0.0
# dist_sch                         0.413302        0.46938      0.002
# dist_clinic                      0.970588       0.901307      0.001
# dist_post                        0.516677       0.505063      0.001
# dist_kind                        0.368011       0.450784      0.001
# dist_rest                        0.345851       0.469084      0.001
# dist_uni                         1.444837       1.124728      0.004
# dist_pharma                       0.35815       0.462408      0.001
# own_type                              NaN            NaN        NaN
# build_mat                             NaN            NaN        NaN
# cond_class                            NaN            NaN        NaN
# has_park                              NaN            NaN        NaN
# has_balcony                           NaN            NaN        NaN
# has_lift                              NaN            NaN        NaN
# has_sec                               NaN            NaN        NaN
# has_store                             NaN            NaN        NaN
# price_z                     784808.026267  430165.453187  119636.88
# src_month                             NaN            NaN        NaN
# loc_code                              NaN            NaN        NaN
# market_volatility            784550.39303  442242.068758  101295.05
# infrastructure_quality          38.099861      37.007349        0.0
# neighborhood_crime_rate         49.878525      28.842192        0.0
# popularity_index                 50.01503      10.033264       7.83
# green_space_ratio                0.999626       0.000489      0.998
# estimated_maintenance_cost      17.600377      10.064985       2.06
# global_economic_index           99.671328       5.879228  89.913197
#
#                                    25%         50%          75%         max
# unit_id                            NaN         NaN          NaN         NaN
# obj_type                           NaN         NaN          NaN         NaN
# dim_m2                           42.24       54.24        69.82      187.31
# n_rooms                            2.0         3.0          3.0         6.0
# floor_no                           2.0         3.0          4.0        29.0
# floor_max                          3.0         4.0          6.0        29.0
# year_built                      1967.0      1994.0       2016.0      2024.0
# dist_centre                        2.0       3.935        6.128      19.686
# n_poi                              7.0        14.0         24.0       212.0
# dist_sch                         0.174       0.288        0.469       5.718
# dist_clinic                      0.353       0.669        1.245       5.818
# dist_post                        0.236       0.392        0.623       5.864
# dist_kind                        0.154        0.26        0.419       5.795
# dist_rest                        0.112       0.226        0.409       5.904
# dist_uni                         0.569        1.11        2.067       5.982
# dist_pharma                       0.14       0.238        0.407       5.752
# own_type                           NaN         NaN          NaN         NaN
# build_mat                          NaN         NaN          NaN         NaN
# cond_class                         NaN         NaN          NaN         NaN
# has_park                           NaN         NaN          NaN         NaN
# has_balcony                        NaN         NaN          NaN         NaN
# has_lift                           NaN         NaN          NaN         NaN
# has_sec                            NaN         NaN          NaN         NaN
# has_store                          NaN         NaN          NaN         NaN
# price_z                     502780.145   690193.49  945012.8075  3921744.77
# src_month                          NaN         NaN          NaN         NaN
# loc_code                           NaN         NaN          NaN         NaN
# market_volatility           493133.245  685495.725   949858.415  4666296.98
# infrastructure_quality            7.99       27.53        58.25      252.72
# neighborhood_crime_rate          24.88       49.84        74.88       100.0
# popularity_index                 43.27       49.99        56.79       95.36
# green_space_ratio                0.999         1.0          1.0         1.0
# estimated_maintenance_cost       10.19       15.56        22.66        87.2
# global_economic_index        93.801401  100.374251   105.234633  109.224288

# %% [markdown]
# ### 3. Missing Value Analysis

# %%
missing_values = train.isna().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  cond_class                117058
# build_mat                  61999
# obj_type                   33820
# floor_no                   27698
# year_built                 25713
# infrastructure_quality     25713
# has_lift                    7727
# dist_uni                    4317
# floor_max                   1921
# dist_clinic                  571
# dist_rest                    391
# dist_pharma                  219
# dist_post                    188
# dist_kind                    163
# dist_sch                     130
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
missing_values.plot(kind='bar')
plt.title('Missing Values by Feature')
plt.xlabel('Features')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### 4. Distribution of Numerical Variables

# %%
numerical_cols = train.select_dtypes(include=['float64', 'int64']).columns.tolist()
numerical_cols.remove('price_z')

n_cols = 4
n_rows = math.ceil(len(numerical_cols) / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 4 * n_rows))
axes = axes.flatten()  

for i, col in enumerate(numerical_cols):
    sns.histplot(train[col], kde=True, bins=30, ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5. Relationship between Numerical Variables and Target Variable

# %%
numerical_cols = train.select_dtypes(include=['float64', 'int64']).columns.tolist()
numerical_cols.remove('price_z')

n_cols = 4
n_rows = math.ceil(len(numerical_cols) / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 5 * n_rows))
axes = axes.flatten()

for i, col in enumerate(numerical_cols):
    sns.regplot(x=train[col], y=train['price_z'], ax=axes[i], scatter_kws={'s': 10}, line_kws={'color': 'red'})
    axes[i].set_title(f'{col} vs price_z')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Correlation Matrix

# %%
correlation = train[numerical_cols + ['price_z']].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
print(correlation)
# Out:
#                               dim_m2   n_rooms  floor_no  floor_max  \
# dim_m2                      1.000000  0.763365 -0.067677  -0.123550
# n_rooms                     0.763365  1.000000 -0.035823  -0.078455
# floor_no                   -0.067677 -0.035823  1.000000   0.665670
# floor_max                  -0.123550 -0.078455  0.665670   1.000000
# year_built                 -0.013937  0.005164  0.064715   0.126588
# dist_centre                 0.042232  0.051075 -0.025474  -0.039538
# n_poi                       0.034440  0.002756  0.032439   0.040917
# dist_sch                    0.062255  0.067386 -0.101636  -0.139826
# dist_clinic                 0.013766  0.039393 -0.121444  -0.176904
# dist_post                   0.053453  0.060387 -0.075030  -0.104399
# dist_kind                   0.066972  0.065115 -0.090331  -0.129294
# dist_rest                   0.031716  0.051771 -0.086864  -0.127848
# dist_uni                    0.031970  0.047288 -0.052271  -0.078968
# dist_pharma                 0.054945  0.063276 -0.100559  -0.136240
# market_volatility           0.548068  0.459598  0.021967   0.030523
# infrastructure_quality      0.014935 -0.002240 -0.059814  -0.116116
# neighborhood_crime_rate    -0.001639 -0.002055 -0.004892   0.000566
# popularity_index            0.002971  0.000518 -0.002454  -0.002986
# green_space_ratio          -0.040085 -0.045972  0.014444   0.020989
# estimated_maintenance_cost  0.690743  0.527112 -0.046116  -0.086002
# global_economic_index      -0.017622 -0.013549  0.008019   0.012653
# price_z                     0.563239  0.472877  0.021565   0.030829
#
#                             year_built  dist_centre     n_poi  dist_sch  \
# dim_m2                       -0.013937     0.042232  0.034440  0.062255
# n_rooms                       0.005164     0.051075  0.002756  0.067386
# floor_no                      0.064715    -0.025474  0.032439 -0.101636
# floor_max                     0.126588    -0.039538  0.040917 -0.139826
# year_built                    1.000000     0.356108 -0.379946  0.258050
# dist_centre                   0.356108     1.000000 -0.445617  0.279881
# n_poi                        -0.379946    -0.445617  1.000000 -0.302156
# dist_sch                      0.258050     0.279881 -0.302156  1.000000
# dist_clinic                   0.247954     0.416199 -0.363999  0.552290
# dist_post                     0.232267     0.252634 -0.316975  0.742249
# dist_kind                     0.114837     0.127477 -0.204967  0.765190
# dist_rest                     0.163691     0.222761 -0.336794  0.756722
# dist_uni                      0.350893     0.522317 -0.433926  0.428372
# dist_pharma                   0.195440     0.242953 -0.295604  0.788256
# market_volatility             0.128910     0.080992  0.170250  0.000313
# infrastructure_quality       -0.918141    -0.326663  0.349903 -0.236978
# neighborhood_crime_rate      -0.001806    -0.002751  0.000734 -0.001128
# popularity_index             -0.001392     0.004323 -0.002754 -0.000389
# green_space_ratio            -0.303103    -0.826293  0.309772 -0.275326
# estimated_maintenance_cost   -0.010516     0.029807  0.022336  0.042754
# global_economic_index         0.001622     0.011883 -0.004053 -0.000502
# price_z                       0.133156     0.083120  0.175313 -0.000169
#
#                             dist_clinic  dist_post  ...  dist_uni  \
# dim_m2                         0.013766   0.053453  ...  0.031970
# n_rooms                        0.039393   0.060387  ...  0.047288
# floor_no                      -0.121444  -0.075030  ... -0.052271
# floor_max                     -0.176904  -0.104399  ... -0.078968
# year_built                     0.247954   0.232267  ...  0.350893
# dist_centre                    0.416199   0.252634  ...  0.522317
# n_poi                         -0.363999  -0.316975  ... -0.433926
# dist_sch                       0.552290   0.742249  ...  0.428372
# dist_clinic                    1.000000   0.488602  ...  0.475459
# dist_post                      0.488602   1.000000  ...  0.327293
# dist_kind                      0.437210   0.716005  ...  0.245403
# dist_rest                      0.507916   0.755295  ...  0.330417
# dist_uni                       0.475459   0.327293  ...  1.000000
# dist_pharma                    0.504567   0.788542  ...  0.353421
# market_volatility             -0.098969  -0.010130  ... -0.013967
# infrastructure_quality        -0.227934  -0.212931  ... -0.322645
# neighborhood_crime_rate       -0.000164   0.002476  ... -0.003848
# popularity_index               0.001046  -0.000662  ...  0.003576
# green_space_ratio             -0.380459  -0.230449  ... -0.468559
# estimated_maintenance_cost     0.010327   0.037009  ...  0.023936
# global_economic_index          0.004976  -0.001929  ...  0.002411
# price_z                       -0.101334  -0.010391  ... -0.014115
#
#                             dist_pharma  market_volatility  \
# dim_m2                         0.054945           0.548068
# n_rooms                        0.063276           0.459598
# floor_no                      -0.100559           0.021967
# floor_max                     -0.136240           0.030523
# year_built                     0.195440           0.128910
# dist_centre                    0.242953           0.080992
# n_poi                         -0.295604           0.170250
# dist_sch                       0.788256           0.000313
# dist_clinic                    0.504567          -0.098969
# dist_post                      0.788542          -0.010130
# dist_kind                      0.817011          -0.014786
# dist_rest                      0.822826          -0.096113
# dist_uni                       0.353421          -0.013967
# dist_pharma                    1.000000          -0.012016
# market_volatility             -0.012016           1.000000
# infrastructure_quality        -0.179253          -0.116811
# neighborhood_crime_rate        0.001338          -0.002856
# popularity_index               0.001243           0.001050
# green_space_ratio             -0.223657          -0.072280
# estimated_maintenance_cost     0.039473           0.378454
# global_economic_index         -0.002281           0.001265
# price_z                       -0.012571           0.972458
#
#                             infrastructure_quality  neighborhood_crime_rate  \
# dim_m2                                    0.014935                -0.001639
# n_rooms                                  -0.002240                -0.002055
# floor_no                                 -0.059814                -0.004892
# floor_max                                -0.116116                 0.000566
# year_built                               -0.918141                -0.001806
# dist_centre                              -0.326663                -0.002751
# n_poi                                     0.349903                 0.000734
# dist_sch                                 -0.236978                -0.001128
# dist_clinic                              -0.227934                -0.000164
# dist_post                                -0.212931                 0.002476
# dist_kind                                -0.104468                 0.000614
# dist_rest                                -0.150206                 0.001062
# dist_uni                                 -0.322645                -0.003848
# dist_pharma                              -0.179253                 0.001338
# market_volatility                        -0.116811                -0.002856
# infrastructure_quality                    1.000000                 0.001812
# neighborhood_crime_rate                   0.001812                 1.000000
# popularity_index                          0.001390                 0.000346
# green_space_ratio                         0.278097                 0.001149
# estimated_maintenance_cost                0.010604                 0.000542
# global_economic_index                    -0.001385                -0.000021
# price_z                                  -0.120988                -0.002497
#
#                             popularity_index  green_space_ratio  \
# dim_m2                              0.002971          -0.040085
# n_rooms                             0.000518          -0.045972
# floor_no                           -0.002454           0.014444
# floor_max                          -0.002986           0.020989
# year_built                         -0.001392          -0.303103
# dist_centre                         0.004323          -0.826293
# n_poi                              -0.002754           0.309772
# dist_sch                           -0.000389          -0.275326
# dist_clinic                         0.001046          -0.380459
# dist_post                          -0.000662          -0.230449
# dist_kind                          -0.003896          -0.135499
# dist_rest                           0.000448          -0.198047
# dist_uni                            0.003576          -0.468559
# dist_pharma                         0.001243          -0.223657
# market_volatility                   0.001050          -0.072280
# infrastructure_quality              0.001390           0.278097
# neighborhood_crime_rate             0.000346           0.001149
# popularity_index                    1.000000          -0.000964
# green_space_ratio                  -0.000964           1.000000
# estimated_maintenance_cost          0.001804          -0.027708
# global_economic_index               0.002183          -0.012413
# price_z                             0.001230          -0.074386
#
#                             estimated_maintenance_cost  global_economic_index  \
# dim_m2                                        0.690743              -0.017622
# n_rooms                                       0.527112              -0.013549
# floor_no                                     -0.046116               0.008019
# floor_max                                    -0.086002               0.012653
# year_built                                   -0.010516               0.001622
# dist_centre                                   0.029807               0.011883
# n_poi                                         0.022336              -0.004053
# dist_sch                                      0.042754              -0.000502
# dist_clinic                                   0.010327               0.004976
# dist_post                                     0.037009              -0.001929
# dist_kind                                     0.046829              -0.003978
# dist_rest                                     0.022696              -0.001407
# dist_uni                                      0.023936               0.002411
# dist_pharma                                   0.039473              -0.002281
# market_volatility                             0.378454               0.001265
# infrastructure_quality                        0.010604              -0.001385
# neighborhood_crime_rate                       0.000542              -0.000021
# popularity_index                              0.001804               0.002183
# green_space_ratio                            -0.027708              -0.012413
# estimated_maintenance_cost                    1.000000              -0.010036
# global_economic_index                        -0.010036               1.000000
# price_z                                       0.389225               0.002049
#
#                              price_z
# dim_m2                      0.563239
# n_rooms                     0.472877
# floor_no                    0.021565
# floor_max                   0.030829
# year_built                  0.133156
# dist_centre                 0.083120
# n_poi                       0.175313
# dist_sch                   -0.000169
# dist_clinic                -0.101334
# dist_post                  -0.010391
# dist_kind                  -0.015575
# dist_rest                  -0.099736
# dist_uni                   -0.014115
# dist_pharma                -0.012571
# market_volatility           0.972458
# infrastructure_quality     -0.120988
# neighborhood_crime_rate    -0.002497
# popularity_index            0.001230
# green_space_ratio          -0.074386
# estimated_maintenance_cost  0.389225
# global_economic_index       0.002049
# price_z                     1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# ### 7. Relationship of Categorical Variables with Target Variable

# %%
categorical_cols = train.select_dtypes(include=['object', 'bool']).columns.tolist()
categorical_cols = [col for col in categorical_cols if col != 'unit_id']

n_cols = 3
n_rows = math.ceil(len(categorical_cols) / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 5 * n_rows))
axes = axes.flatten()

for i, col in enumerate(categorical_cols):
    sns.boxplot(x=col, y='price_z', data=train, ax=axes[i])
    axes[i].set_title(f'{col} vs price_z')
    axes[i].tick_params(axis='x', rotation=45)

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. Outlier Analysis – IQR and Z-score

# %%
z_scores = train[numerical_cols].apply(zscore)
outlier_zscore = (z_scores.abs() > 3).sum()

outlier_iqr = {}
for col in numerical_cols:
    Q1 = train[col].quantile(0.25)
    Q3 = train[col].quantile(0.75)
    IQR = Q3 - Q1
    is_outlier = (train[col] < (Q1 - 1.5 * IQR)) | (train[col] > (Q3 + 1.5 * IQR))
    outlier_iqr[col] = is_outlier.sum()

print("Outliers (Z-score):\n", outlier_zscore.sort_values(ascending=False))
print("Outliers (IQR):\n", pd.Series(outlier_iqr).sort_values(ascending=False))
# Out:
# Outliers (Z-score):
#  n_poi                         4171
# market_volatility             2956
# dim_m2                        2359
# estimated_maintenance_cost    2252
# n_rooms                       1300
# dist_centre                   1274
# popularity_index               430
# green_space_ratio              358
# dist_uni                         0
# neighborhood_crime_rate          0
# infrastructure_quality           0
# dist_pharma                      0
# dist_kind                        0
# dist_rest                        0
# dist_post                        0
# dist_clinic                      0
# dist_sch                         0
# year_built                       0
# floor_max                        0
# floor_no                         0
# global_economic_index            0
# dtype: int64
# Outliers (IQR):
#  n_poi                         14199
# dist_sch                      11944
# dist_clinic                   11731
# dist_pharma                   10943
# floor_max                     10897
# dist_kind                     10096
# floor_no                       9851
# dist_rest                      9802
# dist_post                      9506
# market_volatility              7827
# dim_m2                         5638
# n_rooms                        5410
# estimated_maintenance_cost     4569
# dist_uni                       3477
# infrastructure_quality         3405
# dist_centre                    2038
# popularity_index               1088
# year_built                      943
# neighborhood_crime_rate           0
# green_space_ratio                 0
# global_economic_index             0
# dtype: int64
