# %%
import pandas as pd
import numpy as np
import optuna
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### 1. Load the preprocessed datasets

# %%
train = pd.read_csv(r"C:\Users\YILMAZ\Desktop\train_fe_scaled.csv")
test = pd.read_csv(r"C:\Users\YILMAZ\Desktop\train_fe_scaled.csv")
# scaled data sets were used

# %% [markdown]
# ### 2. Define features and target variable

# %%
target = "price_z"
X_train = train.drop(columns=[target])
y_train = train[target]

# %% [markdown]
# ### 3. Define the objective function for Optuna

# %%
def objective(trial):
    alpha = trial.suggest_float('alpha', 1.0, 1000.0, log=True)
    model = Ridge(alpha=alpha, random_state=42)

    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    rmse = -cross_val_score(model, X_train, y_train,
                            cv=cv,
                            scoring='neg_root_mean_squared_error').mean()
    return rmse

# %% [markdown]
# ### 4. Run Optuna study to find the best alpha (regularization strength)

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50, timeout=900)

print("\n Best hyperparameter found by Optuna:")
print(study.best_params)
# Out:
# [I 2025-11-04 15:02:58,082] A new study created in memory with name: no-name-d9923da7-1d66-42f9-a1ea-352f06dd14f0
# [I 2025-11-04 15:02:58,627] Trial 0 finished with value: 170107.64636189083 and parameters: {'alpha': 101.6752851378999}. Best is trial 0 with value: 170107.64636189083.
# [I 2025-11-04 15:02:59,102] Trial 1 finished with value: 170105.7876609606 and parameters: {'alpha': 1.636953657506596}. Best is trial 1 with value: 170105.7876609606.
# [I 2025-11-04 15:02:59,507] Trial 2 finished with value: 170105.7879489374 and parameters: {'alpha': 1.2384967338390285}. Best is trial 1 with value: 170105.7876609606.
# [I 2025-11-04 15:02:59,928] Trial 3 finished with value: 170105.79774066826 and parameters: {'alpha': 10.469363354372394}. Best is trial 1 with value: 170105.7876609606.
# [I 2025-11-04 15:03:00,356] Trial 4 finished with value: 170105.81482999126 and parameters: {'alpha': 14.954724468401034}. Best is trial 1 with value: 170105.7876609606.
# [I 2025-11-04 15:03:00,749] Trial 5 finished with value: 170105.78781189196 and parameters: {'alpha': 1.4170925914363928}. Best is trial 1 with value: 170105.7876609606.
# [I 2025-11-04 15:03:01,273] Trial 6 finished with value: 170105.79290317284 and parameters: {'alpha': 8.559925091268935}. Best is trial 1 with value: 170105.7876609606.
# [I 2025-11-04 15:03:01,740] Trial 7 finished with value: 170105.7875549037 and parameters: {'alpha': 1.8118504217512603}. Best is trial 7 with value: 170105.7875549037.
# [I 2025-11-04 15:03:02,258] Trial 8 finished with value: 170105.79785156797 and parameters: {'alpha': 10.507301533905128}. Best is trial 7 with value: 170105.7875549037.
# [I 2025-11-04 15:03:02,714] Trial 9 finished with value: 170105.79937427846 and parameters: {'alpha': 11.009656893034016}. Best is trial 7 with value: 170105.7875549037.
# [I 2025-11-04 15:03:03,426] Trial 10 finished with value: 170225.62932135694 and parameters: {'alpha': 956.815115645292}. Best is trial 7 with value: 170105.7875549037.
# [I 2025-11-04 15:03:03,831] Trial 11 finished with value: 170105.78716238728 and parameters: {'alpha': 3.0033722753598533}. Best is trial 11 with value: 170105.78716238728.
# [I 2025-11-04 15:03:04,246] Trial 12 finished with value: 170105.78715479333 and parameters: {'alpha': 3.3201998869515617}. Best is trial 12 with value: 170105.78715479333.
# [I 2025-11-04 15:03:04,652] Trial 13 finished with value: 170106.35747904752 and parameters: {'alpha': 57.10328821744514}. Best is trial 12 with value: 170105.78715479333.
# [I 2025-11-04 15:03:05,117] Trial 14 finished with value: 170105.78762120352 and parameters: {'alpha': 4.7431437103254375}. Best is trial 12 with value: 170105.78715479333.
# [I 2025-11-04 15:03:14,397] Trial 36 finished with value: 170105.82280722936 and parameters: {'alpha': 16.544627187038383}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:14,795] Trial 37 finished with value: 170105.78797620352 and parameters: {'alpha': 1.204852792005503}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:15,201] Trial 38 finished with value: 170105.78753283672 and parameters: {'alpha': 1.8510477164271701}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:15,586] Trial 39 finished with value: 170105.79073093762 and parameters: {'alpha': 7.431157817480717}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:15,981] Trial 40 finished with value: 170105.80449704593 and parameters: {'alpha': 12.503352328458181}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:16,386] Trial 41 finished with value: 170105.78715341183 and parameters: {'alpha': 3.1661312293794563}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:16,770] Trial 42 finished with value: 170105.78764435375 and parameters: {'alpha': 4.780321261027651}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:17,177] Trial 43 finished with value: 170105.78755180564 and parameters: {'alpha': 1.8172873036262844}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:17,594] Trial 44 finished with value: 170105.79275841662 and parameters: {'alpha': 8.49219843993573}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:17,979] Trial 45 finished with value: 170105.7872212448 and parameters: {'alpha': 3.8026985335608723}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:18,454] Trial 46 finished with value: 170105.78784225564 and parameters: {'alpha': 1.3760291744544932}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:18,880] Trial 47 finished with value: 170105.78800432262 and parameters: {'alpha': 5.273616585865152}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:19,319] Trial 48 finished with value: 170105.7871562987 and parameters: {'alpha': 3.089561486502779}. Best is trial 31 with value: 170105.7871533184.
# [I 2025-11-04 15:03:19,743] Trial 49 finished with value: 170105.7874314812 and parameters: {'alpha': 2.0478069323740495}. Best is trial 31 with value: 170105.7871533184.
#  Best hyperparameter found by Optuna:
# {'alpha': 3.2715013713811003}

# %% [markdown]
# ### 5. Train the Ridge model using the best alpha

# %%
best_model = Ridge(alpha=study.best_params['alpha'], random_state=42)
best_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=3.2715013713811003, random_state=42)

# %% [markdown]
# ### 6. Evaluate model performance using 5-fold cross-validation

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=42)

cv_rmse = -cross_val_score(best_model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=cv)
cv_mae = -cross_val_score(best_model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv)
cv_r2 = cross_val_score(best_model, X_train, y_train, scoring='r2', cv=cv)

print("\n Tuned Ridge Regression 5-Fold Cross-Validation Results:")
print(f" RMSE: {cv_rmse.mean():,.2f} ± {cv_rmse.std():,.2f}")
print(f" MAE: {cv_mae.mean():,.2f} ± {cv_mae.std():,.2f}")
print(f" R²: {cv_r2.mean():.4f} ± {cv_r2.std():.4f}")
# Out:
#  Tuned Ridge Regression 5-Fold Cross-Validation Results:
#  RMSE: 170,105.79 ± 2,707.45
#  MAE: 118,579.04 ± 626.37
#  R²: 0.8436 ± 0.0018
